# %%
import numpy as np
import open3d as o3d
import copy
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
# 平移-相对位置
mesh = o3d.geometry.TriangleMesh.create_coordinate_frame()
mesh_tx = copy.deepcopy(mesh).translate(np.array([1,0,0]))
mesh_ty = copy.deepcopy(mesh).translate(np.array([0,1,0]))
print(f'center of mesh tx: {mesh_tx.get_center()}' )
print(f'center of mesh ty: {mesh_ty.get_center()}' )
o3d.visualization.draw_geometries([mesh, mesh_tx,mesh_ty])
# Out:
# center of mesh tx: [1.05167549 0.05167549 0.05167549]
# center of mesh ty: [0.05167549 1.05167549 0.05167549]

# %%
# 平移-到指定位置
mesh = o3d.geometry.TriangleMesh.create_coordinate_frame()
mesh_mv = copy.deepcopy(mesh).translate(np.array([2,2,2]),relative=False) # 设置relative=False
print(f'center of mesh mv: {mesh_mv.get_center()}' )
o3d.visualization.draw_geometries([mesh, mesh_mv])
# Out:
# center of mesh mv: [2. 2. 2.]

# %%
# 旋转-欧拉角xyz
mesh = o3d.geometry.TriangleMesh.create_coordinate_frame()
mesh_r = copy.deepcopy(mesh)
R = mesh.get_rotation_matrix_from_xyz((np.pi/2,0,np.pi/4))
mesh_r.rotate(R,center=(0,0,0))
o3d.visualization.draw_geometries([mesh, mesh_r])

# %%
# 先平移，后旋转
mesh = o3d.geometry.TriangleMesh.create_coordinate_frame()
mesh_r = copy.deepcopy(mesh).translate(np.array([2,0,0]))
mesh_r.rotate(mesh.get_rotation_matrix_from_xyz((np.pi/2,0,np.pi/4)),center=(0,0,0))
o3d.visualization.draw_geometries([mesh, mesh_r])

# %%
# 缩放
mesh = o3d.geometry.TriangleMesh.create_coordinate_frame()
mesh_s = copy.deepcopy(mesh).translate(np.array([2,0,0]))
mesh_s.scale(0.5, center = mesh_s.get_center())
o3d.visualization.draw_geometries([mesh, mesh_s])
